# %% [markdown]
# # Result Dataset: 2D input

# %%
# %%capture
import bencher as bch
from bencher.example.meta.benchable_objects import BenchableDataSetResult

run_cfg = bch.BenchRunCfg()
run_cfg.level = 2
benchable = BenchableDataSetResult()
bench = benchable.to_bench(run_cfg)
res = bench.plot_sweep(input_vars=["value", "scale"], result_vars=["result_ds"])

# %%
from bokeh.io import output_notebook

output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b880fbdd-bef0-6095-8586-29d360efeb39">Loading BokehJS ...</span>
#     </div>
# Column
#     [0] Column(name='Plots View')
#         [0] Markdown(str, name='Sweeping value vs scale')
#         [1] Column
#             [0] Markdown(str)
#             [1] LaTeX(str, renderer='mathjax')
#             [2] Accordion
#                 [0] Markdown(str, width=800)
#         [2] Markdown(str)
#     [1] Column
#         [0] Row
#             [0] Column(name='value vs scale', styles={'background': 'rgb(255.0,...})
#                 [0] Row(name='value vs scale', styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=91)
#                     [1] Row(name='value', styles={'background': 'rgb(242.25...})
#                         [0] Column(name='value', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=91)
#                             [1] DataFrame(DataFrame)
#                         [1] Column(name='value', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=91)
#                             [1] DataFrame(DataFrame)
#                 [1] Row(name='value vs scale', styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=91)
#                     [1] Row(name='value', styles={'background': 'rgb(242.25...})
#                         [0] Column(name='value', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=91)
#                             [1] DataFrame(DataFrame)
#                         [1] Column(name='value', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=91)
#                             [1] DataFrame(DataFrame)
#     [2] Markdown(str, width=800)
