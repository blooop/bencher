# %% [markdown]
# # Result String: 0D input

# %%
# %%capture
import bencher as bch
from bencher.example.meta.benchable_objects import BenchableStringResult
run_cfg = bch.BenchRunCfg()
run_cfg.level = 3
benchable = BenchableStringResult()
bench = benchable.to_bench(run_cfg)
res = bench.plot_sweep(input_vars=["label"], result_vars=["report"])

# %%
from bokeh.io import output_notebook
output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="609aa876-72f3-da19-8374-d10cd5818754">Loading BokehJS ...</span>
#     </div>
# Column
#     [0] Column(name='Plots View')
#         [0] Markdown(str, name='Sweeping label')
#         [1] Column
#             [0] Markdown(str)
#             [1] LaTeX(str, renderer='mathjax')
#             [2] Accordion
#                 [0] Markdown(str, width=800)
#         [2] Markdown(str)
#     [1] Column
#         [0] Row
#             [0] Column(name='label', styles={'background': 'rgb(242.25...})
#                 [0] Row(name='label', styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=77)
#                     [1] Markdown(str)
#                 [1] Row(name='label', styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=77)
#                     [1] Markdown(str)
#                 [2] Row(name='label', styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=77)
#                     [1] Markdown(str)
#     [2] Markdown(str, width=800)
