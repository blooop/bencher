# %% [markdown]
# # Result String: 1D input

# %%
# %%capture
import bencher as bch
from bencher.example.meta.benchable_objects import BenchableStringResult

run_cfg = bch.BenchRunCfg()
run_cfg.level = 3
benchable = BenchableStringResult()
bench = benchable.to_bench(run_cfg)
res = bench.plot_sweep(input_vars=["label", "value"], result_vars=["report"])

# %%
from bokeh.io import output_notebook

output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b1ca2e5f-5729-2faf-2deb-00ca06d5173f">Loading BokehJS ...</span>
#     </div>
# Column
#     [0] Column(name='Plots View')
#         [0] Markdown(str, name='Sweeping label vs value')
#         [1] Column
#             [0] Markdown(str)
#             [1] LaTeX(str, renderer='mathjax')
#             [2] Accordion
#                 [0] Markdown(str, width=800)
#         [2] Markdown(str)
#     [1] Column
#         [0] Row
#             [0] Column(name='label vs value', styles={'background': 'rgb(255.0,...})
#                 [0] Row(name='label vs value', styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=91)
#                     [1] Row(name='label', styles={'background': 'rgb(242.25...})
#                         [0] Column(name='label', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=77)
#                             [1] Markdown(str)
#                         [1] Column(name='label', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=77)
#                             [1] Markdown(str)
#                         [2] Column(name='label', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=77)
#                             [1] Markdown(str)
#                 [1] Row(name='label vs value', styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=91)
#                     [1] Row(name='label', styles={'background': 'rgb(242.25...})
#                         [0] Column(name='label', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=77)
#                             [1] Markdown(str)
#                         [1] Column(name='label', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=77)
#                             [1] Markdown(str)
#                         [2] Column(name='label', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=77)
#                             [1] Markdown(str)
#                 [2] Row(name='label vs value', styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=91)
#                     [1] Row(name='label', styles={'background': 'rgb(242.25...})
#                         [0] Column(name='label', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=77)
#                             [1] Markdown(str)
#                         [1] Column(name='label', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=77)
#                             [1] Markdown(str)
#                         [2] Column(name='label', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=77)
#                             [1] Markdown(str)
#     [2] Markdown(str, width=800)
