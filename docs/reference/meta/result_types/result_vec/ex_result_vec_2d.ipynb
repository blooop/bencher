# %% [markdown]
# # Result Vec: 2D input

# %%
# %%capture
import bencher as bch
from bencher.example.meta.benchable_objects import BenchableVecResult

run_cfg = bch.BenchRunCfg()
run_cfg.level = 2
benchable = BenchableVecResult()
bench = benchable.to_bench(run_cfg)
res = bench.plot_sweep(input_vars=["x", "y"], result_vars=["position"])

# %%
from bokeh.io import output_notebook

output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="7a41f81b-8eea-f699-406f-2670181ff33b">Loading BokehJS ...</span>
#     </div>
# Column
#     [0] Column(name='Plots View')
#         [0] Markdown(str, name='Sweeping x vs y')
#         [1] Column
#             [0] Markdown(str)
#             [1] LaTeX(str, renderer='mathjax')
#             [2] Accordion
#                 [0] Markdown(str, width=800)
#         [2] Markdown(str)
#     [1] Column
#         [0] Markdown(str)
#     [2] Markdown(str, width=800)
