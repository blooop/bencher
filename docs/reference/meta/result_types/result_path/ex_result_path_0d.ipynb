# %% [markdown]
# # Result Path: 0D input

# %%
# %%capture
import bencher as bch
from bencher.example.meta.benchable_objects import BenchablePathResult

run_cfg = bch.BenchRunCfg()
run_cfg.level = 3
benchable = BenchablePathResult()
bench = benchable.to_bench(run_cfg)
res = bench.plot_sweep(input_vars=["content"], result_vars=["file_result"])

# %%
from bokeh.io import output_notebook

output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="e2c1c83c-8e89-b9c8-d299-8f23f92be032">Loading BokehJS ...</span>
#     </div>
# Column
#     [0] Column(name='Plots View')
#         [0] Markdown(str, name='Sweeping content')
#         [1] Column
#             [0] Markdown(str)
#             [1] LaTeX(str, renderer='mathjax')
#             [2] Accordion
#                 [0] Markdown(str, width=800)
#         [2] Markdown(str)
#     [1] Column
#         [0] Row
#             [0] Column(name='content', styles={'background': 'rgb(242.25...})
#                 [0] Row(name='content', styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=112)
#                     [1] FileDownload(_transfers=1, data='data:text/plain;charset=U..., embed=True, file='/home/ags/projects/benche..., filename='report_a_f969489e-68e7-48..., label='Download report_a_f969489...)
#                 [1] Row(name='content', styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=112)
#                     [1] FileDownload(_transfers=1, data='data:text/plain;charset=U..., embed=True, file='/home/ags/projects/benche..., filename='report_b_9bbdcb3c-7d0a-40..., label='Download report_b_9bbdcb3...)
#                 [2] Row(name='content', styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=112)
#                     [1] FileDownload(_transfers=1, data='data:text/plain;charset=U..., embed=True, file='/home/ags/projects/benche..., filename='report_c_cd0288f4-5482-43..., label='Download report_c_cd0288f...)
#     [2] Markdown(str, width=800)
