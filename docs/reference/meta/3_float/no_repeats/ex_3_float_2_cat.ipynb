# %% [markdown]
# # 3 Float, 2 Categorical

# %%
# %%capture
import bencher as bch

from bencher.example.meta.example_meta import BenchableObject

run_cfg = bch.BenchRunCfg()
run_cfg.repeats = 1
run_cfg.level = 4
run_cfg.over_time = False
benchable = BenchableObject()
bench = benchable.to_bench(run_cfg)
res = bench.plot_sweep(
    input_vars=[
        "float1",
        "float2",
        {"name": "float3", "values": None, "max_level": 3, "samples": None},
        "wave",
        "variant",
    ],
    result_vars=["distance", "sample_noise"],
)

# %%
from bokeh.io import output_notebook

output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b07bacf3-0318-4733-a782-cc8ad5ed3fa7">Loading BokehJS ...</span>
#     </div>
# Column
#     [0] Column(name='Plots View')
#         [0] Markdown(str, name='Sweeping float1 v...)
#         [1] Column
#             [0] Markdown(str)
#             [1] LaTeX(str, renderer='mathjax')
#             [2] Accordion
#                 [0] Markdown(str, width=800)
#         [2] Markdown(str)
#     [1] Column
#         [0] Row
#             [0] Column(name='float1 vs float2 v..., styles={'background': 'rgb(255.0,...})
#                 [0] Row(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=91)
#                     [1] Column(name='float1 vs float2 v..., styles={'background': 'rgb(249.69...})
#                         [0] Row(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=70)
#                             [1] Row(name='float1 vs float2 v..., styles={'background': 'rgb(242.25...})
#                                 [0] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [2] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                         [1] Row(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=70)
#                             [1] Row(name='float1 vs float2 v..., styles={'background': 'rgb(242.25...})
#                                 [0] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [2] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                 [1] Row(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=91)
#                     [1] Column(name='float1 vs float2 v..., styles={'background': 'rgb(249.69...})
#                         [0] Row(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=70)
#                             [1] Row(name='float1 vs float2 v..., styles={'background': 'rgb(242.25...})
#                                 [0] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [2] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                         [1] Row(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=70)
#                             [1] Row(name='float1 vs float2 v..., styles={'background': 'rgb(242.25...})
#                                 [0] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [2] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#             [1] Column(name='float1 vs float2 v..., styles={'background': 'rgb(255.0,...})
#                 [0] Row(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=91)
#                     [1] Column(name='float1 vs float2 v..., styles={'background': 'rgb(249.69...})
#                         [0] Row(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=70)
#                             [1] Row(name='float1 vs float2 v..., styles={'background': 'rgb(242.25...})
#                                 [0] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [2] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                         [1] Row(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=70)
#                             [1] Row(name='float1 vs float2 v..., styles={'background': 'rgb(242.25...})
#                                 [0] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [2] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                 [1] Row(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=91)
#                     [1] Column(name='float1 vs float2 v..., styles={'background': 'rgb(249.69...})
#                         [0] Row(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=70)
#                             [1] Row(name='float1 vs float2 v..., styles={'background': 'rgb(242.25...})
#                                 [0] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [2] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                         [1] Row(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=70)
#                             [1] Row(name='float1 vs float2 v..., styles={'background': 'rgb(242.25...})
#                                 [0] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                                 [2] Column(name='float1 vs float2 v..., styles={'border-bottom': '...})
#                                     [0] Markdown(str, align=('center', 'center'), width=98)
#                                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#     [2] Markdown(str, width=800)
