# %% [markdown]
# # 0 Float, 3 Categorical

# %%
# %%capture
import bencher as bch

from bencher.example.meta.example_meta import BenchableObject

run_cfg = bch.BenchRunCfg()
run_cfg.repeats = 1
run_cfg.level = 4
run_cfg.over_time = True
benchable = BenchableObject()
benchable.noise_scale = max(0.1, 0.0)
bench = benchable.to_bench(run_cfg)
time_offsets = [0.0, 0.5, 1.0]
for i, offset in enumerate(time_offsets):
    benchable._time_offset = offset
    run_cfg.clear_cache = True
    run_cfg.clear_history = i == 0
    res = bench.plot_sweep(
        "over_time",
        input_vars=["wave", "variant", "transform"],
        result_vars=["distance", "sample_noise"],
        run_cfg=run_cfg,
    )

# %%
from bokeh.io import output_notebook

output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d56f7881-ecc6-43bd-be6f-d5ca538b3bfa">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'distance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/IPython/core/formatters.py:1036, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#    1033     method = get_real_method(obj, self.print_method)
#    1035     if method is not None:
# -> 1036         return method(include=include, exclude=exclude)
#    1037     return None
#    1038 else:
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/panel/viewable.py:853, in Viewable._repr_mimebundle_(self, include, exclude)
#     851 resources = 'inline' if config.inline and not state._is_pyodide else 'cdn'
#     852 with set_resource_mode(resources):
# --> 853     model = self._render_model(doc, comm)
#     854 if config.embed:
#     855     return render_model(model)
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/panel/viewable.py:768, in Viewable._render_model(self, doc, comm)
#     766 if comm is None:
#     767     comm = state._comm_manager.get_server_comm()
# --> 768 model = self.get_root(doc, comm)
#     770 if self._design and self._design.theme.bokeh_theme:
#     771     doc.theme = self._design.theme.bokeh_theme
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/panel/layout/base.py:329, in Panel.get_root(self, doc, comm, preprocess)
#     325 def get_root(
#     326     self, doc: Document | None = None, comm: Comm | None = None,
#     327     preprocess: bool = True
#     328 ) -> Model:
# --> 329     root = super().get_root(doc, comm, preprocess)
#     330     # ALERT: Find a better way to handle this
#     331     if hasattr(root, 'styles') and 'overflow-x' in root.styles:
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/panel/viewable.py:698, in Renderable.get_root(self, doc, comm, preprocess)
#     696 wrapper = self._design._wrapper(self)
#     697 if wrapper is self:
# --> 698     root = self._get_model(doc, comm=comm)
#     699     if preprocess:
#     700         self._preprocess(root)
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/panel/layout/base.py:313, in Panel._get_model(self, doc, root, parent, comm)
#     311 root = root or model
#     312 self._models[root.ref['id']] = (model, parent)
# --> 313 objects, _ = self._get_objects(model, [], doc, root, comm)
#     314 props = self._get_properties(doc)
#     315 props[self._property_mapping['objects']] = objects
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/panel/layout/base.py:295, in Panel._get_objects(self, model, old_objects, doc, root, comm)
#     293 else:
#     294     try:
# --> 295         child = pane._get_model(doc, root, model, comm)
#     296     except RerenderError as e:
#     297         if e.layout is not None and e.layout is not self:
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/panel/layout/base.py:313, in Panel._get_model(self, doc, root, parent, comm)
#     311 root = root or model
#     312 self._models[root.ref['id']] = (model, parent)
# --> 313 objects, _ = self._get_objects(model, [], doc, root, comm)
#     314 props = self._get_properties(doc)
#     315 props[self._property_mapping['objects']] = objects
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/panel/layout/base.py:295, in Panel._get_objects(self, model, old_objects, doc, root, comm)
#     293 else:
#     294     try:
# --> 295         child = pane._get_model(doc, root, model, comm)
#     296     except RerenderError as e:
#     297         if e.layout is not None and e.layout is not self:
#
#     [... skipping similar frames: Panel._get_model at line 313 (3 times), Panel._get_objects at line 295 (3 times)]
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/panel/layout/base.py:313, in Panel._get_model(self, doc, root, parent, comm)
#     311 root = root or model
#     312 self._models[root.ref['id']] = (model, parent)
# --> 313 objects, _ = self._get_objects(model, [], doc, root, comm)
#     314 props = self._get_properties(doc)
#     315 props[self._property_mapping['objects']] = objects
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/panel/layout/base.py:295, in Panel._get_objects(self, model, old_objects, doc, root, comm)
#     293 else:
#     294     try:
# --> 295         child = pane._get_model(doc, root, model, comm)
#     296     except RerenderError as e:
#     297         if e.layout is not None and e.layout is not self:
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/panel/pane/holoviews.py:487, in HoloViews._get_model(self, doc, root, parent, comm)
#     485     plot = self.object
#     486 else:
# --> 487     plot = self._render(doc, comm, root)
#     489 plot.pane = self
#     490 backend = plot.renderer.backend
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/panel/pane/holoviews.py:581, in HoloViews._render(self, doc, comm, root)
#     578     if comm:
#     579         kwargs['comm'] = comm
# --> 581 return renderer.get_plot(self.object, **kwargs)
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/plotting/bokeh/renderer.py:70, in BokehRenderer.get_plot(self_or_cls, obj, doc, renderer, **kwargs)
#      63 @bothmethod
#      64 def get_plot(self_or_cls, obj, doc=None, renderer=None, **kwargs):
#      65     """Given a HoloViews Viewable return a corresponding plot instance.
#      66     Allows supplying a document attach the plot to, useful when
#      67     combining the bokeh model with another plot.
#      68
#      69     """
# ---> 70     plot = super().get_plot(obj, doc, renderer, **kwargs)
#      71     if plot.document is None:
#      72         plot.document = Document() if self_or_cls.notebook_context else curdoc()
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/plotting/renderer.py:239, in Renderer.get_plot(self_or_cls, obj, doc, renderer, comm, **kwargs)
#     236     defaults = [kd.default for kd in plot.dimensions]
#     237     init_key = tuple(v if d is None else d for v, d in
#     238                      zip(plot.keys[0], defaults, strict=None))
# --> 239     plot.update(init_key)
#     240 else:
#     241     plot = obj
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/plotting/plot.py:958, in DimensionedPlot.update(self, key)
#     956 def update(self, key):
#     957     if len(self) == 1 and key in (0, self.keys[0]) and not self.drawn:
# --> 958         return self.initialize_plot()
#     959     item = self.__getitem__(key)
#     960     self.traverse(lambda x: setattr(x, '_updated', True))
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/plotting/bokeh/element.py:2191, in ElementPlot.initialize_plot(self, ranges, plot, plots, source)
#    2189     element = self.hmap.last
#    2190 key = util.wrap_tuple(self.hmap.last_key)
# -> 2191 ranges = self.compute_ranges(self.hmap, key, ranges)
#    2192 self.current_ranges = ranges
#    2193 self.current_frame = element
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/plotting/plot.py:617, in DimensionedPlot.compute_ranges(self, obj, key, ranges)
#     613     # Only compute ranges if not axiswise on a composite plot
#     614     # or not framewise on a Overlay or ElementPlot
#     615     if (not (axiswise and not isinstance(obj, HoloMap)) or
#     616         (not framewise and isinstance(obj, HoloMap))):
# --> 617         self._compute_group_range(group, elements, ranges, framewise,
#     618                                   axiswise, robust, self.top_level,
#     619                                   prev_frame)
#     620 self.ranges.update(ranges)
#     621 return ranges
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/plotting/plot.py:727, in DimensionedPlot._compute_group_range(cls, group, elements, ranges, framewise, axiswise, robust, top_level, prev_frame)
#     725     data_range = ds.range(el_dim, dimension_range=False)
#     726 else:
# --> 727     data_range = el.range(el_dim, dimension_range=False)
#     729 data_ranges[(el, el_dim)] = data_range
#     730 if dtype is not None and dtype_kind(dtype) in 'uif' and robust:
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/core/data/__init__.py:204, in PipelineMeta.pipelined.<locals>.pipelined_fn(*args, **kwargs)
#     201     inst._in_method = True
#     203 try:
# --> 204     result = method_fn(*args, **kwargs)
#     205     if PipelineMeta.disable:
#     206         return result
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/element/raster.py:958, in HeatMap.range(self, dim, data_range, dimension_range)
#     956     drange = None
#     957 finally:
# --> 958     self.gridded._binned = False
#     959 if drange is not None:
#     960     return drange
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/element/raster.py:919, in HeatMap.gridded(self)
#     916 @property
#     917 def gridded(self):
#     918     if self._gridded is None:
# --> 919         self._gridded = categorical_aggregate2d(self)
#     920     return self._gridded
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/param/parameterized.py:5929, in ParameterizedFunction.__new__(class_, *args, **params)
#    5927 inst = class_.instance()
#    5928 inst.param._set_name(class_.__name__)
# -> 5929 return inst.__call__(*args,**params)
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/core/operation.py:218, in Operation.__call__(self, element, **kwargs)
#     216 kwargs['link_dataset'] = self._propagate_dataset
#     217 kwargs['link_inputs'] = self.p.link_inputs
# --> 218 return element.apply(self, **kwargs)
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/core/accessors.py:43, in AccessorPipelineMeta.pipelined.<locals>.pipelined_call(*args, **kwargs)
#      40     inst._obj._in_method = True
#      42 try:
# ---> 43     result = __call__(*args, **kwargs)
#      45     if not in_method:
#      46         init_op = factory.instance(
#      47             output_type=type(inst),
#      48             kwargs={'mode': getattr(inst, 'mode', None)},
#      49         )
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/core/accessors.py:200, in Apply.__call__(self, apply_function, streams, link_inputs, link_dataset, dynamic, per_element, **kwargs)
#     198 if hasattr(apply_function, 'dynamic'):
#     199     inner_kwargs['dynamic'] = False
# --> 200 new_obj = apply_function(self._obj, **inner_kwargs)
#     201 if (link_dataset and isinstance(self._obj, Dataset) and
#     202     isinstance(new_obj, Dataset) and new_obj._dataset is None):
#     203     new_obj._dataset = self._obj.dataset
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/core/operation.py:212, in Operation.__call__(self, element, **kwargs)
#     208         return element.clone([(k, self._apply(el, key=k))
#     209                               for k, el in element.items()])
#     210     elif ((self._per_element and isinstance(element, Element)) or
#     211           (not self._per_element and isinstance(element, ViewableElement))):
# --> 212         return self._apply(element)
#     213 elif 'streams' not in kwargs:
#     214     kwargs['streams'] = self.p.streams
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/core/operation.py:141, in Operation._apply(self, element, key)
#     139     if not in_method:
#     140         element._in_method = True
# --> 141 ret = self._process(element, key)
#     142 if hasattr(element, '_in_method') and not in_method:
#     143     element._in_method = in_method
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/element/util.py:248, in categorical_aggregate2d._process(self, obj, key)
#     244     raise ValueError("Must have at two dimensions to aggregate over"
#     245                      "and one value dimension to aggregate on.")
#     247 obj = Dataset(obj, datatype=['dataframe'])
# --> 248 return self._aggregate_dataset_pandas(obj)
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/holoviews/element/util.py:230, in categorical_aggregate2d._aggregate_dataset_pandas(self, obj)
#     228 shape = tuple(d.shape[0] for d in data)
#     229 for vdim in obj.vdims:
# --> 230     data += (reindexed[vdim.name].values.reshape(shape).T,)
#     231 return obj.clone(data, datatype=self.p.datatype, label=label)
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/pandas/core/frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File ~/projects/bencher/.pixi/envs/default/lib/python3.13/site-packages/pandas/core/indexes/base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'distance'
# Column
#     [0] Column(name='Plots View')
#         [0] Markdown(str, name='over_time')
#         [1] Column
#             [0] Markdown(str)
#             [1] LaTeX(str, renderer='mathjax')
#             [2] Accordion
#                 [0] Markdown(str, width=800)
#         [2] Markdown(str)
#     [1] Column
#         [0] Row
#             [0] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                 [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Row
#                         [0] HoloViews(DynamicMap, height=600, sizing_mode='fixed', width=600)
#                         [1] WidgetBox(align=('end', 'start'))
#                             [0] DiscreteSlider(name='over_time (time)', options={'2026-03-04 09:13:27': np...}, value=np.datetime64('2026-03-04T...)
#                 [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Row
#                         [0] HoloViews(DynamicMap, height=600, sizing_mode='fixed', width=600)
#                         [1] WidgetBox(align=('end', 'start'))
#                             [0] DiscreteSlider(name='over_time (time)', options={'2026-03-04 09:13:27': np...}, value=np.datetime64('2026-03-04T...)
#             [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                 [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Row
#                         [0] HoloViews(DynamicMap, height=600, sizing_mode='fixed', width=600)
#                         [1] WidgetBox(align=('end', 'start'))
#                             [0] DiscreteSlider(name='over_time (time)', options={'2026-03-04 09:13:27': np...}, value=np.datetime64('2026-03-04T...)
#                 [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Row
#                         [0] HoloViews(DynamicMap, height=600, sizing_mode='fixed', width=600)
#                         [1] WidgetBox(align=('end', 'start'))
#                             [0] DiscreteSlider(name='over_time (time)', options={'2026-03-04 09:13:27': np...}, value=np.datetime64('2026-03-04T...)
#         [1] Row
#             [0] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                 [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Row
#                         [0] HoloViews(DynamicMap)
#                         [1] WidgetBox(align=('end', 'start'))
#                             [0] DiscreteSlider(name='over_time (time)', options={'2026-03-04 09:13:27': np...}, value=np.datetime64('2026-03-04T...)
#                 [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Row
#                         [0] HoloViews(DynamicMap)
#                         [1] WidgetBox(align=('end', 'start'))
#                             [0] DiscreteSlider(name='over_time (time)', options={'2026-03-04 09:13:27': np...}, value=np.datetime64('2026-03-04T...)
#             [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                 [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Row
#                         [0] HoloViews(DynamicMap)
#                         [1] WidgetBox(align=('end', 'start'))
#                             [0] DiscreteSlider(name='over_time (time)', options={'2026-03-04 09:13:27': np...}, value=np.datetime64('2026-03-04T...)
#                 [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Row
#                         [0] HoloViews(DynamicMap)
#                         [1] WidgetBox(align=('end', 'start'))
#                             [0] DiscreteSlider(name='over_time (time)', options={'2026-03-04 09:13:27': np...}, value=np.datetime64('2026-03-04T...)
#     [2] Markdown(str, width=800)
