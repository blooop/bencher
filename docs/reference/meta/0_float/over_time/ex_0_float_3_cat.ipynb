# %% [markdown]
# # 0 Float, 3 Categorical

# %%
# %%capture
import bencher as bch

from bencher.example.meta.example_meta import BenchableObject

run_cfg = bch.BenchRunCfg()
run_cfg.repeats = 1
run_cfg.level = 4
run_cfg.over_time = True
benchable = BenchableObject()
benchable.noise_scale = max(0.1, 0.0)
bench = benchable.to_bench(run_cfg)
time_offsets = [0.0, 0.5, 1.0]
for i, offset in enumerate(time_offsets):
    benchable._time_offset = offset
    run_cfg.clear_cache = True
    run_cfg.clear_history = i == 0
    res = bench.plot_sweep(
        "over_time",
        input_vars=["wave", "variant", "transform"],
        result_vars=["distance", "sample_noise"],
        run_cfg=run_cfg,
    )

# %%
from bokeh.io import output_notebook

output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f8e403f0-95fe-4ace-92d8-27c4768a092b">Loading BokehJS ...</span>
#     </div>
# Column
#     [0] Column(name='Plots View')
#         [0] Markdown(str, name='over_time')
#         [1] Column
#             [0] Markdown(str)
#             [1] LaTeX(str, renderer='mathjax')
#             [2] Accordion
#                 [0] Markdown(str, width=800)
#         [2] Markdown(str)
#     [1] Column
#         [0] Row
#             [0] Row(name='wave vs variant v..., styles={'background': 'rgb(249.69...})
#                 [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(Bars, height=600, sizing_mode='fixed', width=600)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(Bars, height=600, sizing_mode='fixed', width=600)
#                 [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(Bars, height=600, sizing_mode='fixed', width=600)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(Bars, height=600, sizing_mode='fixed', width=600)
#                 [2] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(Bars, height=600, sizing_mode='fixed', width=600)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(Bars, height=600, sizing_mode='fixed', width=600)
#             [1] Row(name='wave vs variant v..., styles={'background': 'rgb(249.69...})
#                 [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(Bars, height=600, sizing_mode='fixed', width=600)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(Bars, height=600, sizing_mode='fixed', width=600)
#                 [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(Bars, height=600, sizing_mode='fixed', width=600)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(Bars, height=600, sizing_mode='fixed', width=600)
#                 [2] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(Bars, height=600, sizing_mode='fixed', width=600)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(Bars, height=600, sizing_mode='fixed', width=600)
#         [1] Row
#             [0] Row(name='wave vs variant v..., styles={'background': 'rgb(249.69...})
#                 [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] Str(None)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] Str(None)
#                 [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] Str(None)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] Str(None)
#                 [2] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] Str(None)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] Str(None)
#             [1] Row(name='wave vs variant v..., styles={'background': 'rgb(249.69...})
#                 [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] Str(None)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] Str(None)
#                 [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] Str(None)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] Str(None)
#                 [2] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] Str(None)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] Str(None)
#         [2] Row
#             [0] Row(name='wave vs variant v..., styles={'background': 'rgb(249.69...})
#                 [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                 [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                 [2] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#             [1] Row(name='wave vs variant v..., styles={'background': 'rgb(249.69...})
#                 [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                 [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                 [2] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=252)
#                     [1] Row(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                         [0] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                         [1] Column(name='wave vs variant v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=126)
#                             [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#     [2] Markdown(str, width=800)
