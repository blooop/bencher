# %% [markdown]
# # 0 Float, 3 Categorical

# %%
# %%capture
import bencher as bch

from bencher.example.meta.example_meta import BenchableObject

run_cfg = bch.BenchRunCfg()
run_cfg.repeats = 10
run_cfg.level = 4
run_cfg.over_time = False
benchable = BenchableObject()
benchable.noise_scale = 0.15
bench = benchable.to_bench(run_cfg)
res = bench.plot_sweep(
    input_vars=["wave", "variant", "transform"], result_vars=["distance", "sample_noise"]
)

# %%
from bokeh.io import output_notebook

output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="b9b53510-9cc5-4d11-87d0-311c4d8affb0">Loading BokehJS ...</span>
#     </div>
# Column
#     [0] Column(name='Plots View')
#         [0] Markdown(str, name='Sweeping wave v...)
#         [1] Column
#             [0] Markdown(str)
#             [1] LaTeX(str, renderer='mathjax')
#             [2] Accordion
#                 [0] Markdown(str, width=800)
#         [2] Markdown(str)
#     [1] Column
#         [0] Row
#             [0] HoloViews(Overlay, height=600, sizing_mode='fixed', width=600)
#             [1] HoloViews(Overlay, height=600, sizing_mode='fixed', width=600)
#         [1] Row
#             [0] Column(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                 [0] Row(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=126)
#                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                 [1] Row(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=126)
#                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#             [1] Column(name='wave vs variant v..., styles={'background': 'rgb(242.25...})
#                 [0] Row(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=126)
#                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                 [1] Row(name='wave vs variant v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=126)
#                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#     [2] Markdown(str, width=800)
