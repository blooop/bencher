# %% [markdown]
# # Optimization: 2 objectives, 2D input

# %%
# %%capture
import bencher as bch
from bencher.example.meta.benchable_objects import BenchableMultiObjective

run_cfg = bch.BenchRunCfg()
run_cfg.level = 2
run_cfg.repeats = 3
run_cfg.use_optuna = True
benchable = BenchableMultiObjective()
benchable.noise_scale = 0.1
bench = benchable.to_bench(run_cfg)
res = bench.plot_sweep(input_vars=["x", "y"], result_vars=["performance", "cost"])

# %%
from bokeh.io import output_notebook

output_notebook()
res.to_auto_plots()
res.to_optuna_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="4dc0a303-e6ca-a481-1bd8-af3272993d74">Loading BokehJS ...</span>
#     </div>
# All vars [<bencher.variables.inputs.FloatSweep object at 0x71796ed650e0>, <bencher.variables.inputs.FloatSweep object at 0x71796ed65700>, <bencher.variables.inputs.IntSweep object at 0x71796ed658c0>]
# Row
#     [0] Column
#         [0] Markdown(str)
#         [1] Plotly(Figure)
#         [2] Column
#             [0] Column
#                 [0] Markdown(str)
#                 [1] Plotly(Figure)
#             [1] Column
#                 [0] Markdown(str)
#                 [1] Plotly(Figure)
#         [3] Row(height=500, scroll=True)
#             [0] Markdown(str)
#     [1] Column
#         [0] Markdown(str)
#         [1] Plotly(Figure)
#         [2] Column
#             [0] Column
#                 [0] Markdown(str)
#                 [1] Plotly(Figure)
#             [1] Column
#                 [0] Markdown(str)
#                 [1] Plotly(Figure)
#         [3] Row
#             [0] Markdown(str)
