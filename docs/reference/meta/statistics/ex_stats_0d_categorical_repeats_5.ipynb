# %% [markdown]
# # Statistics: 5 repeats, categorical

# %%
# %%capture
import bencher as bch
from bencher.example.meta.example_meta import BenchableObject
run_cfg = bch.BenchRunCfg()
run_cfg.repeats = 5
run_cfg.level = 3
benchable = BenchableObject()
benchable.noise_scale = 0.15
bench = benchable.to_bench(run_cfg)
res = bench.plot_sweep(input_vars=["wave"], result_vars=["distance"])

# %%
from bokeh.io import output_notebook
output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="eb37b743-8fbc-7be0-2635-2736dbb740bb">Loading BokehJS ...</span>
#     </div>
# Column
#     [0] Column(name='Plots View')
#         [0] Markdown(str, name='Sweeping wave')
#         [1] Column
#             [0] Markdown(str)
#             [1] LaTeX(str, renderer='mathjax')
#             [2] Accordion
#                 [0] Markdown(str, width=800)
#         [2] Markdown(str)
#     [1] Column
#         [0] Row
#             [0] HoloViews(Overlay, height=600, sizing_mode='fixed', width=600)
#     [2] Markdown(str, width=800)
