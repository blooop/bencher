# %% [markdown]
# # Statistics: 1 repeat, categorical

# %%
# %%capture
import bencher as bch
from bencher.example.meta.example_meta import BenchableObject

run_cfg = bch.BenchRunCfg()
run_cfg.repeats = 1
run_cfg.level = 3
benchable = BenchableObject()
bench = benchable.to_bench(run_cfg)
res = bench.plot_sweep(input_vars=["wave"], result_vars=["distance"])

# %%
from bokeh.io import output_notebook

output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="bb0cb471-6813-7f22-4654-6385754341b3">Loading BokehJS ...</span>
#     </div>
# Column
#     [0] Column(name='Plots View')
#         [0] Markdown(str, name='Sweeping wave')
#         [1] Column
#             [0] Markdown(str)
#             [1] LaTeX(str, renderer='mathjax')
#             [2] Accordion
#                 [0] Markdown(str, width=800)
#         [2] Markdown(str)
#     [1] Column
#         [0] Row
#             [0] HoloViews(Bars, height=600, sizing_mode='fixed', width=600)
#     [2] Markdown(str, width=800)
