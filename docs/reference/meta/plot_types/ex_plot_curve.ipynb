# %% [markdown]
# # Plot Type: Curve

# %%
# %%capture
import bencher as bch
from bencher.example.meta.example_meta import BenchableObject
run_cfg = bch.BenchRunCfg()
run_cfg.repeats = 5
run_cfg.level = 3
benchable = BenchableObject()
benchable.noise_scale = 0.15
bench = benchable.to_bench(run_cfg)
res = bench.plot_sweep(input_vars=["float1"], result_vars=["distance"])

# %%
from bokeh.io import output_notebook
output_notebook()
res.to_curve()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="54fbdc2c-3b6d-b781-66b5-7d2672686e8f">Loading BokehJS ...</span>
#     </div>
# Row
#     [0] HoloViews(Overlay, height=600, sizing_mode='fixed', width=600)
