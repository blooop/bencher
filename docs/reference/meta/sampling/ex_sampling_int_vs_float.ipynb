# %% [markdown]
# # Sampling: Int Vs Float

# %%
# %%capture
import bencher as bch
from bencher.example.meta.benchable_objects import BenchableIntFloat

run_cfg = bch.BenchRunCfg()
run_cfg.level = 3
benchable = BenchableIntFloat()
bench = benchable.to_bench(run_cfg)
res = bench.plot_sweep(input_vars=["int_input", "float_input"], result_vars=["output"])

# %%
from bokeh.io import output_notebook

output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="325a1e97-36f0-ab76-5b28-f4ebece06320">Loading BokehJS ...</span>
#     </div>
# Column
#     [0] Column(name='Plots View')
#         [0] Markdown(str, name='Sweeping int_input v...)
#         [1] Column
#             [0] Markdown(str)
#             [1] LaTeX(str, renderer='mathjax')
#             [2] Accordion
#                 [0] Markdown(str, width=800)
#         [2] Markdown(str)
#     [1] Column
#         [0] Row
#             [0] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#     [2] Markdown(str, width=800)
