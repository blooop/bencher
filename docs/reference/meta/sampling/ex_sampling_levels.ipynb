# %% [markdown]
# # Sampling: Levels

# %%
# %%capture
import bencher as bch
from bencher.example.meta.example_meta import BenchMeta
bench = BenchMeta().to_bench()
bench.plot_sweep(
    title="Level-based sampling resolution",
    input_vars=[
        bch.p("float_vars", [1, 2]),
        bch.p("level", [2, 3, 4, 5]),
    ],
    const_vars=dict(categorical_vars=0),
)
res = bench.get_result()

# %%
from bokeh.io import output_notebook
output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d2e9849a-c223-6899-a79f-b13ab167a985">Loading BokehJS ...</span>
#     </div>
# Column
#     [0] Column(name='Plots View')
#         [0] Markdown(str, name='Level-based s...)
#         [1] Column
#             [0] Markdown(str)
#             [1] LaTeX(str, renderer='mathjax')
#             [2] Accordion
#                 [0] Markdown(str, width=800)
#         [2] Markdown(str)
#     [1] Column
#         [0] Row
#             [0] Column(name='float_vars vs level', styles={'background': 'rgb(255.0,...})
#                 [0] Row(name='float_vars vs level', styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=98)
#                     [1] Row(name='float_vars', styles={'background': 'rgb(242.25...})
#                         [0] Column(name='float_vars', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=133)
#                             [1] Column
#                                 [0] Row
#                                     [0] HoloViews(Curve, height=500, sizing_mode='fixed', width=500)
#                         [1] Column(name='float_vars', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=133)
#                             [1] Column
#                                 [0] Row
#                                     [0] HoloViews(HeatMap, height=500, sizing_mode='fixed', width=500)
#                 [1] Row(name='float_vars vs level', styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=98)
#                     [1] Row(name='float_vars', styles={'background': 'rgb(242.25...})
#                         [0] Column(name='float_vars', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=133)
#                             [1] Column
#                                 [0] Row
#                                     [0] HoloViews(Curve, height=500, sizing_mode='fixed', width=500)
#                         [1] Column(name='float_vars', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=133)
#                             [1] Column
#                                 [0] Row
#                                     [0] HoloViews(HeatMap, height=500, sizing_mode='fixed', width=500)
#                 [2] Row(name='float_vars vs level', styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=98)
#                     [1] Row(name='float_vars', styles={'background': 'rgb(242.25...})
#                         [0] Column(name='float_vars', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=133)
#                             [1] Column
#                                 [0] Row
#                                     [0] HoloViews(Curve, height=500, sizing_mode='fixed', width=500)
#                         [1] Column(name='float_vars', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=133)
#                             [1] Column
#                                 [0] Row
#                                     [0] HoloViews(HeatMap, height=500, sizing_mode='fixed', width=500)
#                 [3] Row(name='float_vars vs level', styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('end', 'center'), width=98)
#                     [1] Row(name='float_vars', styles={'background': 'rgb(242.25...})
#                         [0] Column(name='float_vars', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=133)
#                             [1] Column
#                                 [0] Row
#                                     [0] HoloViews(Curve, height=500, sizing_mode='fixed', width=500)
#                         [1] Column(name='float_vars', styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('center', 'center'), width=133)
#                             [1] Column
#                                 [0] Row
#                                     [0] HoloViews(HeatMap, height=500, sizing_mode='fixed', width=500)
#     [2] Markdown(str, width=800)
