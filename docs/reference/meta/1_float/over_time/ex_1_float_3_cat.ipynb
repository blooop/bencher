# %% [markdown]
# # 1 Float, 3 Categorical

# %%
# %%capture
import bencher as bch

from bencher.example.meta.example_meta import BenchableObject

run_cfg = bch.BenchRunCfg()
run_cfg.repeats = 1
run_cfg.level = 4
run_cfg.over_time = True
benchable = BenchableObject()
benchable.noise_scale = max(0.1, 0.0)
bench = benchable.to_bench(run_cfg)
time_offsets = [0.0, 0.5, 1.0]
for i, offset in enumerate(time_offsets):
    benchable._time_offset = offset
    run_cfg.clear_cache = True
    run_cfg.clear_history = i == 0
    res = bench.plot_sweep(
        "over_time",
        input_vars=["float1", "wave", "variant", "transform"],
        result_vars=["distance", "sample_noise"],
        run_cfg=run_cfg,
    )

# %%
from bokeh.io import output_notebook

output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c4ea0823-81d1-4941-9706-35e5ee657b32">Loading BokehJS ...</span>
#     </div>
# Column
#     [0] Column(name='Plots View')
#         [0] Markdown(str, name='over_time')
#         [1] Column
#             [0] Markdown(str)
#             [1] LaTeX(str, renderer='mathjax')
#             [2] Accordion
#                 [0] Markdown(str, width=800)
#         [2] Markdown(str)
#     [1] Column
#         [0] Row
#             [0] Row(name='float1 vs wave v..., styles={'background': 'rgb(249.69...})
#                 [0] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Column(name='float1 vs wave v..., styles={'background': 'rgb(242.25...})
#                         [0] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(DynamicMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time (time)', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#                         [1] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(DynamicMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time (time)', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#                 [1] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Column(name='float1 vs wave v..., styles={'background': 'rgb(242.25...})
#                         [0] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(DynamicMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time (time)', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#                         [1] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(DynamicMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time (time)', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#             [1] Row(name='float1 vs wave v..., styles={'background': 'rgb(249.69...})
#                 [0] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Column(name='float1 vs wave v..., styles={'background': 'rgb(242.25...})
#                         [0] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(DynamicMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time (time)', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#                         [1] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(DynamicMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time (time)', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#                 [1] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Column(name='float1 vs wave v..., styles={'background': 'rgb(242.25...})
#                         [0] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(DynamicMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time (time)', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#                         [1] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(DynamicMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time (time)', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#         [1] Row
#             [0] Row(name='float1 vs wave v..., styles={'background': 'rgb(249.69...})
#                 [0] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Column(name='float1 vs wave v..., styles={'background': 'rgb(242.25...})
#                         [0] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(HoloMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#                         [1] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(HoloMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#                 [1] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Column(name='float1 vs wave v..., styles={'background': 'rgb(242.25...})
#                         [0] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(HoloMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#                         [1] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(HoloMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#             [1] Row(name='float1 vs wave v..., styles={'background': 'rgb(249.69...})
#                 [0] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Column(name='float1 vs wave v..., styles={'background': 'rgb(242.25...})
#                         [0] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(HoloMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#                         [1] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(HoloMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#                 [1] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=126)
#                     [1] Column(name='float1 vs wave v..., styles={'background': 'rgb(242.25...})
#                         [0] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(HoloMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#                         [1] Row(name='float1 vs wave v..., styles={'border-bottom': '...})
#                             [0] Markdown(str, align=('end', 'center'), width=91)
#                             [1] Row
#                                 [0] HoloViews(HoloMap, height=600, sizing_mode='fixed', width=600)
#                                 [1] WidgetBox(align=('end', 'start'))
#                                     [0] DiscreteSlider(name='over_time', options={'2026-03-03 13:56:54': np...}, value=np.datetime64('2026-03-03T...)
#     [2] Markdown(str, width=800)
