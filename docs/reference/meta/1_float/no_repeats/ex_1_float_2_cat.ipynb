# %% [markdown]
# # 1 Float, 2 Categorical

# %%
# %%capture
import bencher as bch

from bencher.example.meta.example_meta import BenchableObject

run_cfg = bch.BenchRunCfg()
run_cfg.repeats = 1
run_cfg.level = 4
run_cfg.over_time = False
benchable = BenchableObject()
bench = benchable.to_bench(run_cfg)
res = bench.plot_sweep(
    input_vars=["float1", "wave", "variant"], result_vars=["distance", "sample_noise"]
)

# %%
from bokeh.io import output_notebook

output_notebook()
res.to_auto_plots()
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f4e0031b-88b8-406a-8644-07a0a9d91ea8">Loading BokehJS ...</span>
#     </div>
# Column
#     [0] Column(name='Plots View')
#         [0] Markdown(str, name='Sweeping float1 v...)
#         [1] Column
#             [0] Markdown(str)
#             [1] LaTeX(str, renderer='mathjax')
#             [2] Accordion
#                 [0] Markdown(str, width=800)
#         [2] Markdown(str)
#     [1] Column
#         [0] Row
#             [0] Row(name='float1 vs wave v..., styles={'background': 'rgb(242.25...})
#                 [0] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=91)
#                     [1] HoloViews(NdOverlay, height=600, sizing_mode='fixed', width=600)
#                 [1] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=91)
#                     [1] HoloViews(NdOverlay, height=600, sizing_mode='fixed', width=600)
#             [1] Row(name='float1 vs wave v..., styles={'background': 'rgb(242.25...})
#                 [0] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=91)
#                     [1] HoloViews(NdOverlay, height=600, sizing_mode='fixed', width=600)
#                 [1] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=91)
#                     [1] HoloViews(NdOverlay, height=600, sizing_mode='fixed', width=600)
#         [1] Row
#             [0] Row(name='float1 vs wave v..., styles={'background': 'rgb(242.25...})
#                 [0] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=91)
#                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                 [1] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=91)
#                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#             [1] Row(name='float1 vs wave v..., styles={'background': 'rgb(242.25...})
#                 [0] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=91)
#                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#                 [1] Column(name='float1 vs wave v..., styles={'border-bottom': '...})
#                     [0] Markdown(str, align=('center', 'center'), width=91)
#                     [1] HoloViews(HeatMap, height=600, sizing_mode='fixed', width=600)
#     [2] Markdown(str, width=800)
